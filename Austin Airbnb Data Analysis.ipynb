# %%
#pip install matplotlib
#pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
import seaborn as sns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def read_excel(file_path):
    df = pd.read_csv(file_path)
    return df
listing_df = read_excel('D:/Projects/Austin Airbnb/listings.csv/Detailed_June_Sept_Listings.csv')
reviews_df = read_excel('D:/Projects/Austin Airbnb/June_Sept Reviews/reviews.csv')
calender_df = read_excel('D:/Projects/Austin Airbnb/June_Sept Calender/calendar.csv')

# %%
listing_df = listing_df.drop(columns = ['listing_url','scrape_id','last_scraped','source','picture_url','host_url','host_thumbnail_url',
                                         'host_picture_url','neighbourhood_group_cleansed','license','minimum_minimum_nights','maximum_minimum_nights',
                                         'minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm','review_scores_cleanliness',
                                         'review_scores_checkin','review_scores_communication','review_scores_location','bathrooms','calendar_updated','last_review',
                                         'review_scores_accuracy','review_scores_value','neighbourhood','reviews_per_month','name','description'],axis=1)

# %%
listing_df['host_is_superhost'] = listing_df['host_is_superhost'].apply(lambda x: 'True' if x == 't' else 'False')
listing_df['host_has_profile_pic'] = listing_df['host_has_profile_pic'].apply(lambda x: 'True' if x == 't' else 'False')
listing_df['host_identity_verified'] = listing_df['host_identity_verified'].apply(lambda x: 'True' if x == 't' else 'False')
listing_df['has_availability'] = listing_df['has_availability'].apply(lambda x: 'True' if x == 't' else 'False')
listing_df['instant_bookable'] = listing_df['instant_bookable'].apply(lambda x: 'True' if x == 't' else 'False')

# %%
listing_df.head(2)
# Out:
#      id                              neighborhood_overview  host_id  \
# 0  5456  My neighborhood is ideally located if you want...     8028
# 1  5769  Quiet neighborhood with lots of trees and good...     8186
#
#    host_name  host_since host_location  \
# 0     Sylvia  2009-02-16    Austin, TX
# 1  Elizabeth  2009-02-19    Austin, TX
#
#                                           host_about host_response_time  \
# 0  I am a licensed Real Estate Broker and owner o...     within an hour
# 1  We're easygoing professionals that enjoy meeti...     within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  97%              True
# 1               100%                  91%              True
#
#   host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0      East Downtown                  1.0                        4.0
# 1  SW Williamson Co.                  1.0                        4.0
#
# ...

# %%
listing_df.loc[listing_df['host_verifications'].isnull(), 'Verification'] = 'Not Verified'

# %%
listing_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone', 'work_email']", "['phone']", "['email']",
#        "['email', 'work_email']", '[]', nan,
#        "['email', 'phone', 'photographer', 'work_email']"], dtype=object)

# %%
verif_list = ['email','phone','work_email']
for ver in listing_df['host_verifications']:
     ver = str(ver)
     ver = ver.replace('[','')
     ver = ver.replace(']','')
     ver.split(",")
# Out:
# 'email', 'phone'
# 'email', 'phone', 'work_email'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone', 'work_email'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone', 'work_email'
# 'email', 'phone', 'work_email'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone', 'work_email'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'phone', 'work_email'
# 'email', 'phone', 'work_email'
# 'email', 'phone', 'work_email'
# 'email', 'phone'
# 'email', 'phone', 'work_email'
# 'email', 'phone', 'work_email'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'phone'
# 'email', 'phone'
# 'email', 'phone', 'work_email'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# 'email', 'phone'
# ...
